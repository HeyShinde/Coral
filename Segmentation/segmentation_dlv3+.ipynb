# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q git+https://github.com/keras-team/keras-cv.git --upgrade
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 8.0 MB/s eta 0:00:00
#   Building wheel for keras-cv (pyproject.toml) ... done

# %%
import os
import random
import glob
import numpy as np
import tensorflow as tf
from dataclasses import dataclass
import cv2
import matplotlib.pyplot as plt

# Set random seed for reproducibility
def system_config(SEED_VALUE):
    random.seed(SEED_VALUE)
    tf.keras.utils.set_random_seed(SEED_VALUE)
    os.environ["CUDA_VISIBLE_DEVICES"] = '0'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['TF_USE_CUDNN'] = "true"

system_config(SEED_VALUE=42)

@dataclass(frozen=True)
class DatasetConfig:
    IMAGE_SIZE: tuple = (256, 256)
    BATCH_SIZE: int = 16
    NUM_CLASSES: int = 2
    BRIGHTNESS_FACTOR: float = 0.2
    CONTRAST_FACTOR: float = 0.2

@dataclass(frozen=True)
class TrainingConfig:
    MODEL: str = "resnet50_v2_imagenet"
    EPOCHS: int = 100
    LEARNING_RATE: float = 1e-4
    CKPT_DIR: str = os.path.join("checkpoints_"+"_".join(MODEL.split("_")[:2]),
                                 "deeplabv3_plus_"+"_".join(MODEL.split("_")[:2])+".weights.h5")
    LOGS_DIR: str = "logs_"+"_".join(MODEL.split("_")[:2])

# Instantiate configuration
data_config = DatasetConfig()
train_config = TrainingConfig()

# Define dataset directories
DATASET_DIR = "/content/drive/MyDrive/dataset"
train_images = glob.glob(os.path.join(DATASET_DIR, "train_images", "*.jpg"))
train_masks = glob.glob(os.path.join(DATASET_DIR, "train_masks", "*.jpg"))
valid_images = glob.glob(os.path.join(DATASET_DIR, "valid_images", "*.jpg"))
valid_masks = glob.glob(os.path.join(DATASET_DIR, "valid_masks", "*.jpg"))

# Ensure the lists are sorted to keep the pairs in sync
train_images.sort()
train_masks.sort()
valid_images.sort()
valid_masks.sort()

def read_image_mask(image_path, mask=False, size=data_config.IMAGE_SIZE):
    image = tf.io.read_file(image_path)
    if mask:
        image = tf.io.decode_image(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.resize(images=image, size=size, method="bicubic")

        image_mask = tf.zeros_like(image)
        cond = image >= 200
        updates = tf.ones_like(image[cond])
        image_mask = tf.tensor_scatter_nd_update(image_mask, tf.where(cond), updates)
        image = tf.cast(image_mask, tf.uint8)
    else:
        image = tf.io.decode_image(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf.image.resize(images=image, size=size, method="bicubic")
        image = tf.cast(tf.clip_by_value(image, 0., 255.), tf.float32)
    return image

def load_data(image_path, mask_path):
    image = read_image_mask(image_path)
    mask = read_image_mask(mask_path, mask=True)
    return {"images": image, "segmentation_masks": mask}

train_data = tf.data.Dataset.from_tensor_slices((train_images, train_masks))
valid_data = tf.data.Dataset.from_tensor_slices((valid_images, valid_masks))

train_ds = train_data.map(lambda image, mask: load_data(image, mask), num_parallel_calls=tf.data.AUTOTUNE)
valid_ds = valid_data.map(lambda image, mask: load_data(image, mask), num_parallel_calls=tf.data.AUTOTUNE)

def unpackage_inputs(inputs):
    images = inputs["images"]
    segmentation_masks = inputs["segmentation_masks"]
    return images, segmentation_masks

id2color = {
    0: (0, 0, 0),  # Background
    1: (102, 204, 255),  # Waterbodies
}

def num_to_rgb(num_arr, color_map=id2color):
    output = np.zeros(num_arr.shape[:2] + (3,))
    for k in color_map.keys():
        output[num_arr == k] = color_map[k]
    return output.astype(np.uint8)

def image_overlay(image, segmented_image):
    alpha = 1.0  # Transparency for the original image.
    beta = 0.7  # Transparency for the segmentation map.
    gamma = 0.0  # Scalar added to each sum.

    image = image.astype(np.uint8)
    segmented_image = cv2.cvtColor(segmented_image, cv2.COLOR_RGB2BGR)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    image = cv2.addWeighted(image, alpha, segmented_image, beta, gamma, image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    return image

def display_image_and_mask(data_list, title_list, figsize, color_mask=False, color_map=id2color):
    rgb_gt_mask = num_to_rgb(data_list[1], color_map=color_map)
    mask_to_overlay = rgb_gt_mask

    if len(data_list) == 3:
        rgb_pred_mask = num_to_rgb(data_list[-1], color_map=color_map)
        mask_to_overlay = rgb_pred_mask

    overlayed_image = image_overlay(data_list[0], mask_to_overlay)
    data_list.append(overlayed_image)

    fig, axes = plt.subplots(nrows=1, ncols=len(data_list), figsize=figsize)

    for idx, axis in enumerate(axes.flat):
        axis.set_title(title_list[idx])
        if title_list[idx] == "GT Mask":
            if color_mask:
                axis.imshow(rgb_gt_mask)
            else:
                axis.imshow(data_list[1], cmap="gray")
        elif title_list[idx] == "Pred Mask":
            if color_mask:
                axis.imshow(rgb_pred_mask)
            else:
                axis.imshow(data_list[-1], cmap="gray")
        else:
            axis.imshow(data_list[idx])
        axis.axis('off')

    plt.show()

# Plot a batch of images and masks to verify correct mapping
plot_train_ds = train_ds.map(unpackage_inputs).batch(3)
image_batch, mask_batch = next(iter(plot_train_ds.take(1)))

titles = ["GT Image", "GT Mask", "Overlayed Mask"]

for image, gt_mask in zip(image_batch, mask_batch):
    gt_mask = tf.squeeze(gt_mask, axis=-1).numpy()
    display_image_and_mask([image.numpy().astype(np.uint8), gt_mask],
                           title_list=titles,
                           figsize=(16,6),
                           color_mask=True)

# %%
import keras_cv
augment_fn = tf.keras.Sequential(
    [
        keras_cv.layers.RandomFlip(),
        keras_cv.layers.RandomBrightness(factor=data_config.BRIGHTNESS_FACTOR,
                                         value_range=(0, 255)),
        keras_cv.layers.RandomContrast(factor=data_config.CONTRAST_FACTOR,
                                       value_range=(0, 255)),
    ]
)
# Out:
# Using TensorFlow backend

# %%
train_dataset = (
                train_ds.shuffle(data_config.BATCH_SIZE)
                .map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE)
                .batch(data_config.BATCH_SIZE)
                .map(unpackage_inputs)
                .prefetch(buffer_size=tf.data.AUTOTUNE)
)

valid_dataset = (
                valid_ds.batch(data_config.BATCH_SIZE)
                .map(unpackage_inputs)
                .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
backbone = keras_cv.models.ResNet50V2Backbone.from_preset(preset = train_config.MODEL,
                                                          input_shape=data_config.IMAGE_SIZE+(3,),
                                                          load_weights = True)
model = keras_cv.models.segmentation.DeepLabV3Plus(
        num_classes=data_config.NUM_CLASSES, backbone=backbone,
    )
print(model.summary())
# Out:
# Downloading from https://www.kaggle.com/api/v1/models/keras/resnetv2/keras/resnet50_v2_imagenet/2/download/config.json...
# 100%|██████████| 886/886 [00:00<00:00, 1.33MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/resnetv2/keras/resnet50_v2_imagenet/2/download/model.weights.h5...
# 100%|██████████| 90.3M/90.3M [00:02<00:00, 46.3MB/s]
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids
# Model: "deep_lab_v3_plus"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  model (Functional)          {'P2': (None, 64, 64, 256)   2355660   ['input_1[0][0]']
#                              , 'P5': (None, 8, 8, 2048)   8
#                              }
#
#  spatial_pyramid_pooling (S  (None, 8, 8, 256)            1553817   ['model[0][1]']
#  patialPyramidPooling)                                    6
#
#  encoder_output_upsampling   (None, 64, 64, 256)          0         ['spatial_pyramid_pooling[0][0
#  (UpSampling2D)                                                     ]']
#
#  sequential_1 (Sequential)   (None, 64, 64, 48)           12480     ['model[0][0]']
#
#  concatenate (Concatenate)   (None, 64, 64, 304)          0         ['encoder_output_upsampling[0]
#                                                                     [0]',
#                                                                      'sequential_1[0][0]']
#
#  sequential_2 (Sequential)   (None, 256, 256, 2)          79360     ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 39194816 (149.52 MB)
# Trainable params: 39145696 (149.33 MB)
# Non-trainable params: 49120 (191.88 KB)
# __________________________________________________________________________________________________
# None

# %%
def mean_iou(y_true, y_pred):

    # Get total number of classes from model output.
    num_classes = y_pred.shape[-1]

    y_true = tf.squeeze(y_true, axis=-1)

    y_true = tf.one_hot(tf.cast(y_true, tf.int32), num_classes, axis=-1)
    y_pred = tf.one_hot(tf.math.argmax(y_pred, axis=-1), num_classes, axis=-1)

    # Intersection: |G ∩ P|. Shape: (batch_size, num_classes)
    intersection = tf.math.reduce_sum(y_true * y_pred, axis=(1, 2))

    # Total Sum: |G| + |P|. Shape: (batch_size, num_classes)
    total = tf.math.reduce_sum(y_true, axis=(1, 2)) + tf.math.reduce_sum(y_pred, axis=(1, 2))

    union = total - intersection

    is_class_present =  tf.cast(tf.math.not_equal(total, 0), dtype=tf.float32)
    num_classes_present = tf.math.reduce_sum(is_class_present, axis=1)

    iou = tf.math.divide_no_nan(intersection, union)
    iou = tf.math.reduce_sum(iou, axis=1) / num_classes_present

    # Compute the mean across the batch axis. Shape: Scalar
    mean_iou = tf.math.reduce_mean(iou)

    return mean_iou

# %%
# Define callbacks including early stopping and model checkpoint
def get_callbacks(
    train_config,
    monitor="val_mean_iou",
    mode="max",
    save_weights_only=True,
    save_best_only=False,
    patience=10
):
    tensorboard_callback = tf.keras.callbacks.TensorBoard(
        log_dir=train_config.LOGS_DIR,
        histogram_freq=20,
        write_graph=False,
        update_freq="epoch",
    )

    checkpoint_dir = "/content/drive/MyDrive/models"

    checkpoint_filepath = os.path.join(checkpoint_dir, train_config.CKPT_DIR) if save_weights_only else train_config.CKPT_DIR.replace(".weights.h5", ".h5")

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=save_weights_only,
        monitor=monitor,
        mode=mode,
        save_best_only=save_best_only,
        verbose=1,
    )

    early_stopping_callback = tf.keras.callbacks.EarlyStopping(
        monitor=monitor,
        patience=patience,
        verbose=1,
        mode=mode,
        restore_best_weights=True
    )

    return [tensorboard_callback, model_checkpoint_callback, early_stopping_callback]

# %%
# Get callbacks.
callbacks = get_callbacks(train_config)
# Define Loss.
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
# Compile model.
model.compile(
    optimizer=tf.keras.optimizers.Adam(train_config.LEARNING_RATE),
    loss=loss_fn,
    metrics=["accuracy", mean_iou],
)

# %%
# Train the model, doing validation at the end of each epoch.
history = model.fit(
    train_dataset,
    epochs=train_config.EPOCHS,
    validation_data=valid_dataset,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 78/78 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9649 - mean_iou: 0.8954
# Epoch 1: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 63s 469ms/step - loss: 0.0880 - accuracy: 0.9649 - mean_iou: 0.8954 - val_loss: 0.3666 - val_accuracy: 0.8986 - val_mean_iou: 0.7736
# Epoch 2/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9658 - mean_iou: 0.8999
# Epoch 2: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 468ms/step - loss: 0.0886 - accuracy: 0.9658 - mean_iou: 0.8999 - val_loss: 0.2958 - val_accuracy: 0.9206 - val_mean_iou: 0.8014
# Epoch 3/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9672 - mean_iou: 0.9026
# Epoch 3: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 475ms/step - loss: 0.0824 - accuracy: 0.9672 - mean_iou: 0.9026 - val_loss: 0.3525 - val_accuracy: 0.9005 - val_mean_iou: 0.7698
# Epoch 4/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9692 - mean_iou: 0.9071
# Epoch 4: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 478ms/step - loss: 0.0776 - accuracy: 0.9692 - mean_iou: 0.9071 - val_loss: 0.2955 - val_accuracy: 0.9246 - val_mean_iou: 0.8162
# Epoch 5/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 0.9696 - mean_iou: 0.9078
# Epoch 5: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 485ms/step - loss: 0.0762 - accuracy: 0.9696 - mean_iou: 0.9078 - val_loss: 0.2582 - val_accuracy: 0.9238 - val_mean_iou: 0.8117
# Epoch 6/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9708 - mean_iou: 0.9099
# Epoch 6: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 493ms/step - loss: 0.0736 - accuracy: 0.9708 - mean_iou: 0.9099 - val_loss: 0.3982 - val_accuracy: 0.8779 - val_mean_iou: 0.7264
# Epoch 7/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9702 - mean_iou: 0.9105
# Epoch 7: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 474ms/step - loss: 0.0759 - accuracy: 0.9702 - mean_iou: 0.9105 - val_loss: 0.3055 - val_accuracy: 0.9080 - val_mean_iou: 0.7865
# Epoch 8/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9717 - mean_iou: 0.9138
# Epoch 8: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 474ms/step - loss: 0.0706 - accuracy: 0.9717 - mean_iou: 0.9138 - val_loss: 0.2836 - val_accuracy: 0.9234 - val_mean_iou: 0.8116
# Epoch 9/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9719 - mean_iou: 0.9149
# Epoch 9: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 464ms/step - loss: 0.0709 - accuracy: 0.9719 - mean_iou: 0.9149 - val_loss: 0.2379 - val_accuracy: 0.9262 - val_mean_iou: 0.8108
# Epoch 10/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9728 - mean_iou: 0.9169
# Epoch 10: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 480ms/step - loss: 0.0687 - accuracy: 0.9728 - mean_iou: 0.9169 - val_loss: 0.2899 - val_accuracy: 0.9199 - val_mean_iou: 0.8045
# Epoch 11/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9743 - mean_iou: 0.9213
# Epoch 11: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 497ms/step - loss: 0.0642 - accuracy: 0.9743 - mean_iou: 0.9213 - val_loss: 0.2508 - val_accuracy: 0.9274 - val_mean_iou: 0.8199
# Epoch 12/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9746 - mean_iou: 0.9209
# Epoch 12: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 500ms/step - loss: 0.0636 - accuracy: 0.9746 - mean_iou: 0.9209 - val_loss: 0.2482 - val_accuracy: 0.9287 - val_mean_iou: 0.8146
# Epoch 13/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9756 - mean_iou: 0.9224
# Epoch 13: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 478ms/step - loss: 0.0610 - accuracy: 0.9756 - mean_iou: 0.9224 - val_loss: 0.3552 - val_accuracy: 0.8891 - val_mean_iou: 0.7428
# Epoch 14/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9758 - mean_iou: 0.9229
# Epoch 14: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 477ms/step - loss: 0.0607 - accuracy: 0.9758 - mean_iou: 0.9229 - val_loss: 0.3020 - val_accuracy: 0.9275 - val_mean_iou: 0.8175
# Epoch 15/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9753 - mean_iou: 0.9226
# Epoch 15: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 481ms/step - loss: 0.0615 - accuracy: 0.9753 - mean_iou: 0.9226 - val_loss: 0.2619 - val_accuracy: 0.9283 - val_mean_iou: 0.8125
# Epoch 16/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9758 - mean_iou: 0.9220
# Epoch 16: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 477ms/step - loss: 0.0610 - accuracy: 0.9758 - mean_iou: 0.9220 - val_loss: 0.3107 - val_accuracy: 0.9152 - val_mean_iou: 0.8008
# Epoch 17/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0698 - accuracy: 0.9727 - mean_iou: 0.9162
# Epoch 17: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 473ms/step - loss: 0.0698 - accuracy: 0.9727 - mean_iou: 0.9162 - val_loss: 0.2574 - val_accuracy: 0.9219 - val_mean_iou: 0.8098
# Epoch 18/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9742 - mean_iou: 0.9189
# Epoch 18: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 489ms/step - loss: 0.0648 - accuracy: 0.9742 - mean_iou: 0.9189 - val_loss: 0.2395 - val_accuracy: 0.9267 - val_mean_iou: 0.8144
# Epoch 19/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9768 - mean_iou: 0.9232
# Epoch 19: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 466ms/step - loss: 0.0580 - accuracy: 0.9768 - mean_iou: 0.9232 - val_loss: 0.2886 - val_accuracy: 0.9265 - val_mean_iou: 0.8149
# Epoch 20/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9775 - mean_iou: 0.9297
# Epoch 20: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 477ms/step - loss: 0.0558 - accuracy: 0.9775 - mean_iou: 0.9297 - val_loss: 0.3500 - val_accuracy: 0.9279 - val_mean_iou: 0.8276
# Epoch 21/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9787 - mean_iou: 0.9301
# Epoch 21: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 42s 524ms/step - loss: 0.0534 - accuracy: 0.9787 - mean_iou: 0.9301 - val_loss: 0.3906 - val_accuracy: 0.9207 - val_mean_iou: 0.8132
# Epoch 22/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9774 - mean_iou: 0.9269
# Epoch 22: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 471ms/step - loss: 0.0568 - accuracy: 0.9774 - mean_iou: 0.9269 - val_loss: 0.2776 - val_accuracy: 0.9258 - val_mean_iou: 0.8147
# Epoch 23/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9780 - mean_iou: 0.9288
# Epoch 23: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 479ms/step - loss: 0.0549 - accuracy: 0.9780 - mean_iou: 0.9288 - val_loss: 0.2555 - val_accuracy: 0.9140 - val_mean_iou: 0.7942
# Epoch 24/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9772 - mean_iou: 0.9262
# Epoch 24: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 474ms/step - loss: 0.0593 - accuracy: 0.9772 - mean_iou: 0.9262 - val_loss: 0.5013 - val_accuracy: 0.9022 - val_mean_iou: 0.7802
# Epoch 25/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9776 - mean_iou: 0.9295
# Epoch 25: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 498ms/step - loss: 0.0575 - accuracy: 0.9776 - mean_iou: 0.9295 - val_loss: 0.3840 - val_accuracy: 0.9141 - val_mean_iou: 0.7894
# Epoch 26/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9788 - mean_iou: 0.9325
# Epoch 26: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 474ms/step - loss: 0.0534 - accuracy: 0.9788 - mean_iou: 0.9325 - val_loss: 0.3075 - val_accuracy: 0.9312 - val_mean_iou: 0.8260
# Epoch 27/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9793 - mean_iou: 0.9330
# Epoch 27: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 483ms/step - loss: 0.0509 - accuracy: 0.9793 - mean_iou: 0.9330 - val_loss: 0.2762 - val_accuracy: 0.9331 - val_mean_iou: 0.8331
# Epoch 28/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9792 - mean_iou: 0.9336
# Epoch 28: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 478ms/step - loss: 0.0521 - accuracy: 0.9792 - mean_iou: 0.9336 - val_loss: 0.3188 - val_accuracy: 0.9331 - val_mean_iou: 0.8332
# Epoch 29/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9796 - mean_iou: 0.9346
# Epoch 29: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 479ms/step - loss: 0.0507 - accuracy: 0.9796 - mean_iou: 0.9346 - val_loss: 0.2458 - val_accuracy: 0.9353 - val_mean_iou: 0.8311
# Epoch 30/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9804 - mean_iou: 0.9351
# Epoch 30: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 493ms/step - loss: 0.0484 - accuracy: 0.9804 - mean_iou: 0.9351 - val_loss: 0.3137 - val_accuracy: 0.9295 - val_mean_iou: 0.8280
# Epoch 31/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9806 - mean_iou: 0.9364
# Epoch 31: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 494ms/step - loss: 0.0482 - accuracy: 0.9806 - mean_iou: 0.9364 - val_loss: 0.2833 - val_accuracy: 0.9333 - val_mean_iou: 0.8348
# Epoch 32/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9813 - mean_iou: 0.9379
# Epoch 32: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 474ms/step - loss: 0.0465 - accuracy: 0.9813 - mean_iou: 0.9379 - val_loss: 0.3017 - val_accuracy: 0.9308 - val_mean_iou: 0.8287
# Epoch 33/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9812 - mean_iou: 0.9366
# Epoch 33: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 470ms/step - loss: 0.0469 - accuracy: 0.9812 - mean_iou: 0.9366 - val_loss: 0.3331 - val_accuracy: 0.9282 - val_mean_iou: 0.8276
# Epoch 34/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9817 - mean_iou: 0.9380
# Epoch 34: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 475ms/step - loss: 0.0449 - accuracy: 0.9817 - mean_iou: 0.9380 - val_loss: 0.2562 - val_accuracy: 0.9359 - val_mean_iou: 0.8343
# Epoch 35/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9819 - mean_iou: 0.9408
# Epoch 35: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 489ms/step - loss: 0.0445 - accuracy: 0.9819 - mean_iou: 0.9408 - val_loss: 0.3580 - val_accuracy: 0.9189 - val_mean_iou: 0.8101
# Epoch 36/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9814 - mean_iou: 0.9375
# Epoch 36: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 486ms/step - loss: 0.0471 - accuracy: 0.9814 - mean_iou: 0.9375 - val_loss: 0.2927 - val_accuracy: 0.9306 - val_mean_iou: 0.8273
# Epoch 37/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9806 - mean_iou: 0.9376
# Epoch 37: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 475ms/step - loss: 0.0494 - accuracy: 0.9806 - mean_iou: 0.9376 - val_loss: 0.2922 - val_accuracy: 0.9301 - val_mean_iou: 0.8211
# Epoch 38/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9816 - mean_iou: 0.9384
# Epoch 38: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 39s 473ms/step - loss: 0.0455 - accuracy: 0.9816 - mean_iou: 0.9384 - val_loss: 0.2580 - val_accuracy: 0.9359 - val_mean_iou: 0.8342
# Epoch 39/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9817 - mean_iou: 0.9390
# Epoch 39: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 40s 486ms/step - loss: 0.0453 - accuracy: 0.9817 - mean_iou: 0.9390 - val_loss: 0.2646 - val_accuracy: 0.9339 - val_mean_iou: 0.8329
# Epoch 40/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9819 - mean_iou: 0.9396
# Epoch 40: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# 78/78 [==============================] - 38s 468ms/step - loss: 0.0456 - accuracy: 0.9819 - mean_iou: 0.9396 - val_loss: 0.3233 - val_accuracy: 0.9160 - val_mean_iou: 0.8041
# Epoch 41/100
# 78/78 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9813 - mean_iou: 0.9400
# Epoch 41: saving model to /content/drive/MyDrive/models/checkpoints_resnet50_v2/deeplabv3_plus_resnet50_v2.weights.h5
# Restoring model weights from the end of the best epoch: 31.
# 78/78 [==============================] - 41s 527ms/step - loss: 0.0461 - accuracy: 0.9813 - mean_iou: 0.9400 - val_loss: 0.3597 - val_accuracy: 0.9237 - val_mean_iou: 0.8176
# Epoch 41: early stopping

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()



# Plot training & validation mean IoU values
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('Model Mean IoU')
plt.ylabel('Mean IoU')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
